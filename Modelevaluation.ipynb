# %%
import numpy as np

# %%
#Example of DataSet
X = np.array([1, 2, 3, 4, 5]) # Feature
y = np.array([2, 4, 5, 4, 5]) # Target

# %%
# add column of 1s for intercept
X_b = np.c_[np.ones((len(X),1)),X]

# %%
#Apply OLS Formula
beta_hat = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
print("Intercept(β0):" , beta_hat[0])
print("Slope (β1):", beta_hat[1])
# Out:
# Intercept(β0): 2.200000000000004
# Slope (β1): 0.6000000000000005

# %%
# Predictions
y_pred = X_b.dot(beta_hat)
print("Predictions:", y_pred)
# Out:
# Predictions: [2.8 3.4 4.  4.6 5.2]

# %%
mse = np.mean((y - y_pred) ** 2)
print("Mean Squared Error (MSE):", mse)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
ss_total = np.sum((y - np.mean(y)) ** 2)
ss_residual = np.sum((y - y_pred) ** 2)

r2 = 1 - (ss_residual / ss_total)
print("R-Squared (R²):", r2)
# Out:
# Mean Squared Error (MSE): 0.48000000000000026
# Root Mean Squared Error (RMSE): 0.6928203230275511
# R-Squared (R²): 0.5999999999999999
